# %% [markdown]
# ## Data Overview

# %% [markdown]
# Alphabet Soup wants a tool that can help it select the applicants for funding with the best chance of success in their ventures.  Using machine learning and neural networks a CSV is received containing more than 34,000 organizations that have received funding from Alphabet Soup over the years.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# - What variable(s) are the target(s) for your model?
#         ‘IS_SUCCESSFUL’ column is my target for the model
# - What variable(s) are the features for your model?
#         ‘CLASSIFICATION’ and ‘APPLICATION_TYPE’ columns are the features for the model
# - What variable(s) should be removed from the input data because they are neither targets nor features?
# 	   ‘Ein’ and ‘NAME’ are removed from the input data because they are neither targets nor features?

# %% [markdown]
# ## Compiling, Training, and Evaluating the Model

# %% [markdown]
# - How many neurons, layers, and activation functions did you select for your neural network model, and why?
# 	I used the unoptimized model as my foundation for the optimized models because it produced results very close to the desired 75% from there, I made small changes to see what would affect the accuracy.
#
# ## Unoptimized:
# -	Accuracy: 0.7291
# -	2 layers: 80, 30
# -	Removed 'EIN' and 'NAME' from the model
# -	activation='relu' epochs=100
# -	Control group, first attempt to see what would happen
# ![image-4.png](attachment:image-4.png)
#
# ## Optimized 1:
# -	Accuracy: 0.7321
# -	included ‘NAME’ back into the model
# -	2 layers: 80, 30
# -	activation='relu’ epochs=100
# -	added back ‘NAME’ to see if that would impact the results, I saw a slight increase
# ![image-3.png](attachment:image-3.png)
#
# ## Optimized 2:
#
# -	Accuracy: 0.7266
# -	included ‘NAME’ back into the model
# -	3 layers: 5,10,15
# -	activation='relu’ epochs=100
# -	with the increase from adding ‘NAME’, I increased the layers to see if that would help but my accuracy decreased
# ![image-2.png](attachment:image-2.png)
#
# ## Optimized 3:
# -	Accuracy: 0.7280
# -	removed 'EIN','NAME','ASK_AMT' from the model
# -	3 layers: 10,30,80
# -	activation='relu' epochs=100
# -	for my final attempt I removed EIN','NAME','ASK_AMT' from the model and added an extra layer. I saw another decrease in accuracy, this attempt did not get me to my desired goal
#
# ![image.png](attachment:image.png)
#
# -	Were you able to achieve the target model performance?
#
#      No, with three attempts, I could not get the accuracy above 73%.
#
#
# -	What steps did you take in your attempts to increase model performance?
#
#
#      What I tried was to add/remove columns and adjust the number of layers to try and get to my goal accuracy. I was not able to achieve it and with more time I believe I could tune it to reach the goal.

# %% [markdown]
# ## Summary

# %% [markdown]
# Deep learning models use multiple layers to learn, since it is machine based the filters help the machine to predict and group the data. With the modifications to each model is clear that the machine with more time could be tuned to the desired 75%. Maybe if I let the data run more epochs, or played with the layers some more, or even tuned the nodes more that could have given me the accuracy I needed.
